# %% [markdown]
# <a href="https://colab.research.google.com/github/Muhammad-Waleed-Source/Exploratory-Data-Analysis/blob/main/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('train.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### Why do EDA
#
# - Model building
# - Analysis and reporting
# - Validate assumptions
# - Handling missing values
# - feature engineering
# - detecting outliers

# %% [markdown]
# ### Remember it is an iterative process

# %% [markdown]
# ### Column Types
#
# - **Numerical** - Age,Fare,PassengerId
# - **Categorical** - Survived, Pclass, Sex, SibSp, Parch,Embarked
# - **Mixed** - Name, Ticket, Cabin

# %% [markdown]
# ### Univariate Analysis
#
# Univariate analysis focuses on analyzing each feature in the dataset independently.
#
# - **Distribution analysis**: The distribution of each feature is examined to identify its shape, central tendency, and dispersion.
#
# - **Identifying potential issues**: Univariate analysis helps in identifying potential problems with the data such as outliers, skewness, and missing values

# %% [markdown]
# #### The shape of a data distribution refers to its overall pattern or form as it is represented on a graph. Some common shapes of data distributions include:
#
# - **Normal Distribution**: A symmetrical and bell-shaped distribution where the mean, median, and mode are equal and the majority of the data falls in the middle of the distribution with gradually decreasing frequencies towards the tails.
#
# - **Skewed Distribution**: A distribution that is not symmetrical, with one tail being longer than the other. It can be either positively skewed (right-skewed) or negatively skewed (left-skewed).
#
# - **Bimodal Distribution**: A distribution with two peaks or modes.
#
# - **Uniform Distribution**: A distribution where all values have an equal chance of occurring.
#
# The shape of the data distribution is important in identifying the presence of outliers, skewness, and the type of statistical tests and models that can be used for further analysis.

# %% [markdown]
# #### **Dispersion** is a statistical term used to describe the spread or variability of a set of data. It measures how far the values in a data set are spread out from the central tendency (mean, median, or mode) of the data.
#
# There are several measures of dispersion, including:
#
# - **Range**: The difference between the largest and smallest values in a data set.
#
# - **Variance**: The average of the squared deviations of each value from the mean of the data set.
#
# - **Standard Deviation**: The square root of the variance. It provides a measure of the spread of the data that is in the same units as the original data.
#
# - **Interquartile range (IQR)**: The range between the first quartile (25th percentile) and the third quartile (75th percentile) of the data.
#
# Dispersion helps to describe the spread of the data, which can help to identify the presence of outliers and skewness in the data.

# %% [markdown]
# ### Steps of doing Univariate Analysis on Numerical columns
#
# - **Descriptive Statistics**: Compute basic summary statistics for the column, such as mean, median, mode, standard deviation, range, and quartiles. These statistics give a general understanding of the distribution of the data and can help identify skewness or outliers.
#
# - **Visualizations**: Create visualizations to explore the distribution of the data. Some common visualizations for numerical data include histograms, box plots, and density plots. These visualizations provide a visual representation of the distribution of the data and can help identify skewness an outliers.
#
# - **Identifying Outliers**: Identify and examine any outliers in the data. Outliers can be identified using visualizations. It is important to determine whether the outliers are due to measurement errors, data entry errors, or legitimate differences in the data, and to decide whether to include or exclude them from the analysis.
#
# - **Skewness**: Check for skewness in the data and consider transforming the data or using robust statistical methods that are less sensitive to skewness, if necessary.
#
# - **Conclusion**: Summarize the findings of the EDA and make decisions about how to proceed with further analysis.

# %% [markdown]
# ### Age
#
# **conclusions**
# - Age is normally(almost) distributed
# - 20% of the values are missing
# - There are some outliers

# %%
print(df['Age'])
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
print(df['Age'].describe())
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
df['Age'].plot(kind='hist')

# there are higher number of passengers with age 20 to 40
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Age'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
print(df['Age'].skew())

# the number is near to the 0 which means it is near to the normally distributed data
# Out:
# 0.38910778230082704

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df['Age'].plot(kind='box', vert=False)
# Out:
# <Axes: >

# %%
df[df['Age'] > 65]

# so we can see here that these outliers are actual values of age col, so we will not remove them
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 33            34         0       2                 Wheadon, Mr. Edward H
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 672          673         0       2           Mitchell, Mr. Henry Michael
# 745          746         0       1          Crosby, Capt. Edward Gifford
# 851          852         0       3                   Svensson, Mr. Johan
#
#       Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 33   male  66.0      0      0  C.A. 24579  10.5000   NaN        S
# 96   male  71.0      0      0    PC 17754  34.6542    A5        C
# 116  male  70.5      0      0      370369   7.7500   NaN        Q
# ...

# %%
print(df['Age'].isnull().sum())
# Out:
# 177

# %%
print((df['Age'].isnull().sum() / len(df['Age']))* 100)

# we have 19% of missing values in Age col
# Out:
# 19.865319865319865

# %% [markdown]
# ### Fare
#
# **conclusions**
#
# - The data is highly(positively) skewed
# - Fare col actually contains the group fare and not the individual fare(This migth be an issue)
# - We need to create a new col called individual fare

# %%
df['Fare'].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
df['Fare'].plot(kind='hist')

# we can see the data is not normally distributed
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Fare'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
print(df["Fare"].skew())

# highly positively skewed
# Out:
# 4.787316519674893

# %%
df['Fare'].plot(kind='box')

# huge number of outliers
# Out:
# <Axes: >

# %%
df[df['Fare'] > 250]
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 27            28         0       1         Fortune, Mr. Charles Alexander
# 88            89         1       1             Fortune, Miss. Mabel Helen
# 258          259         1       1                       Ward, Miss. Anna
# 311          312         1       1             Ryerson, Miss. Emily Borie
# 341          342         1       1         Fortune, Miss. Alice Elizabeth
# 438          439         0       1                      Fortune, Mr. Mark
# 679          680         1       1     Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1                 Lesurer, Mr. Gustave J
# 742          743         1       1  Ryerson, Miss. Susan Parker "Suzette"
#
#         Sex   Age  SibSp  Parch    Ticket      Fare            Cabin Embarked
# 27     male  19.0      3      2     19950  263.0000      C23 C25 C27        S
# ...

# %% [markdown]
# From the above data we came to know that, for a family the fare is calculated as a whole which is assigned to each family member. Like Ticket number 19950 is assigned to 4 persons and they have the Fare of 263 dollors and they all are family members (Group Fare).

# %%
df['Fare'].isnull().sum()

# no missing value
# Out:
# np.int64(0)

# %% [markdown]
# ### Steps of doing Univariate Analysis on Categorical columns
#
# **Descriptive Statistics**: Compute the frequency distribution of the categories in the column. This will give a general understanding of the distribution of the categories and their relative frequencies.
#
# **Visualizations**: Create visualizations to explore the distribution of the categories. Some common visualizations for categorical data include count plots and pie charts. These visualizations provide a visual representation of the distribution of the categories and can help identify any patterns or anomalies in the data.
#
# **Missing Values**: Check for missing values in the data and decide how to handle them. Missing values can be imputed or excluded from the analysis, depending on the research question and the data set.
#
# **Conclusion**: Summarize the findings of the EDA and make decisions about how to proceed with further analysis.

# %% [markdown]
# ### Survived
#
# **conclusions**
#
# - More than 50% passengers died.
# - No missing values.

# %%
df['Survived'].value_counts()

# 342 passengers survived
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df['Survived'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Survived'>

# %%
df['Survived'].value_counts().plot(kind='pie', autopct='%0.1f%%')

# More than 50% could not survived
# Out:
# <Axes: ylabel='count'>

# %%
df['Survived'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Pclass
#
# **conclusions**
#
# - Surprisingly less people travelled in Pclass 2(economical) than Pclass 1(VIP).
# - No missing values.

# %%
df['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
df['Pclass'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Pclass'>

# %%
df['Pclass'].value_counts().plot(kind='pie', autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['Pclass'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Sex
#
# **conclusions**
#
# - No missing values.

# %%
df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df['Sex'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Sex'>

# %%
df['Sex'].value_counts().plot(kind='pie', autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['Sex'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### SibSp
#
# **conclusions**
#
# - No missing values.

# %%
df['SibSp'].value_counts()
# Out:
# SibSp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64

# %%
df['SibSp'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='SibSp'>

# %%
df['SibSp'].value_counts().plot(kind='pie', autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['SibSp'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Parch
#
# **conclusions**
# - Parch(ParentChild) and SibSp(SiblingSpouse) cols can be merged to form  a new col call family_size
# - Create a new col called is_alone

# %%
df['Parch'].value_counts()
# Out:
# Parch
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: count, dtype: int64

# %%
df['Parch'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Parch'>

# %%
df['Parch'].value_counts().plot(kind='pie', autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['Parch'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Embarked
#
# **conclusions**
#
# - Two missing values

# %%
df['Embarked'].value_counts()

# S: Southampton (England)
# C: Cherbourg (France)
# Q: Queenstown (Ireland)
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
df['Embarked'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Embarked'>

# %%
df['Embarked'].value_counts().plot(kind='pie', autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['Embarked'].isnull().sum()
# Out:
# np.int64(2)

# %% [markdown]
# ### Steps of doing Univariate Analysis on Mixed columns
#
# - We have to do feature engineering on these cols first to convert these cols into a format on which we can do Univariate analysis(numerical or categorical cols).

# %% [markdown]
# ### Steps of doing Bivariate Analysis
#
# - Select 2 cols
# - Understand type of relationship
#     1. **Numerical - Numerical**<br>
#         a. You can plot graphs like scatterplot(regression plots), 2D histplot, 2D KDEplots<br>
#         b. Check correlation coefficent to check linear relationship
#     2. **Numerical - Categorical** - create visualizations that compare the distribution of the numerical data across different categories of the categorical data.<br>
#         a. You can plot graphs like barplot, boxplot, kdeplot violinplot even scatterplots<br>
#     3. **Categorical - Categorical**<br>
#         a. You can create cross-tabulations or contingency tables that show the distribution of values in one categorical column, grouped by the values in the other categorical column.<br>
#         b. You can plots like heatmap, stacked barplots, treemaps
#
# - Write your conclusions

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# For bivariate analysis we should pick the most important col for us (eg. Survived col for creating a ML model to predict that the new passenger will survive or not) with all other cols.
#
# Another col could be Age, because it has some missing values and for filling them we should know how the age is distributed among other cols.

# %% [markdown]
# # Survived Col

# %% [markdown]
# ### Survived Col with Catagorical Cols

# %% [markdown]
# ### Survived vs Pclass
# As both are categorical cols so we need to create contingency table

# %% [markdown]
# Conclusions:
#
# - Pclass 3 is the most dangerous class as more number of passengers died there.
#
# - Pclass 1 is the safest class as less number of passengers died there.

# %%
# how much survived and how much died in each Pclass

pd.crosstab(df['Survived'], df['Pclass'])
# Out:
# Pclass      1   2    3
# Survived
# 0          80  97  372
# 1         136  87  119

# %%
# in percentage

pd.crosstab(df['Survived'], df['Pclass'], normalize='columns')*100
# Out:
# Pclass            1          2          3
# Survived
# 0         37.037037  52.717391  75.763747
# 1         62.962963  47.282609  24.236253

# %%
# heatmap
sns.heatmap(pd.crosstab(df['Survived'], df['Pclass'], normalize='columns')*100)
# Out:
# <Axes: xlabel='Pclass', ylabel='Survived'>

# %% [markdown]
# ### Survived vs Sex
# As both are categorical cols so we need to create contingency table

# %% [markdown]
# Conclusions:
#
# - The avg of females survived is greater than males

# %%
pd.crosstab(df['Survived'], df['Sex'], normalize='columns')*100
# Out:
# Sex          female       male
# Survived
# 0         25.796178  81.109185
# 1         74.203822  18.890815

# %%
sns.heatmap(pd.crosstab(df['Survived'], df['Sex'], normalize='columns')*100)
# Out:
# <Axes: xlabel='Sex', ylabel='Survived'>

# %% [markdown]
# ### Survived vs Embarked
# As both are categorical cols so we need to create contingency table

# %%
pd.crosstab(df['Survived'], df['Embarked'], normalize='columns')*100
# Out:
# Embarked          C          Q          S
# Survived
# 0         44.642857  61.038961  66.304348
# 1         55.357143  38.961039  33.695652

# %% [markdown]
# As we can see here, at the Embarked C the number of survivals are more as compared to other two. So may be that is because of Sex(female) or Pclass(1).

# %%
# checking the relation with Sex

pd.crosstab(df['Sex'], df['Embarked'], normalize='columns')*100
# Out:
# Embarked          C          Q          S
# Sex
# female    43.452381  46.753247  31.521739
# male      56.547619  53.246753  68.478261

# %% [markdown]
# Our first assumption failed because at every stop males are more as compared to females, so checking it with Pclass.

# %%
pd.crosstab(df['Pclass'], df['Embarked'], normalize='columns')*100
# Out:
# Embarked          C          Q          S
# Pclass
# 1         50.595238   2.597403  19.720497
# 2         10.119048   3.896104  25.465839
# 3         39.285714  93.506494  54.813665

# %% [markdown]
# This is the reason that at Embarked C more number people entered Pclass 1. That is the reason at C more people survived.
#
# So the relation is not with the Embarked but with the Pclass.

# %% [markdown]
# ### Survived Col with Numerical Cols

# %% [markdown]
# ### Survived vs Age
#
# As Survived col is categorical and Age col is numerical so we need to create plots (kde plot here)

# %%
# for survived
df[df['Survived'] == 1]['Age'].plot(kind='kde', label='Survived')

# for died
df[df['Survived'] == 0]['Age'].plot(kind='kde', label='Died')

plt.legend()
plt.show()

# %%
df[df['Pclass'] == 1]['Age'].mean()
# Out:
# np.float64(38.233440860215055)

# %% [markdown]
# So age is a very important col to analyze who will survive and die based on age.(Dependent)

# %% [markdown]
# ## Feature Engineering on Fare col

# %%
df['SibSp'].value_counts()
# Out:
# SibSp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64

# %%
df[df['SibSp'] == 8]
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 159          160         0       3         Sage, Master. Thomas Henry    male
# 180          181         0       3       Sage, Miss. Constance Gladys  female
# 201          202         0       3                Sage, Mr. Frederick    male
# 324          325         0       3           Sage, Mr. George John Jr    male
# 792          793         0       3            Sage, Miss. Stella Anna  female
# 846          847         0       3           Sage, Mr. Douglas Bullen    male
# 863          864         0       3  Sage, Miss. Dorothy Edith "Dolly"  female
#
#      Age  SibSp  Parch    Ticket   Fare Cabin Embarked
# 159  NaN      8      2  CA. 2343  69.55   NaN        S
# 180  NaN      8      2  CA. 2343  69.55   NaN        S
# 201  NaN      8      2  CA. 2343  69.55   NaN        S
# 324  NaN      8      2  CA. 2343  69.55   NaN        S
# 792  NaN      8      2  CA. 2343  69.55   NaN        S
# ...

# %% [markdown]
# Above we can see is each person is travelling with 8+2=10 people and one himself so total is 11(including him), but there are only 7 members.

# %%
df[df['Ticket'] == 'CA. 2343']
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 159          160         0       3         Sage, Master. Thomas Henry    male
# 180          181         0       3       Sage, Miss. Constance Gladys  female
# 201          202         0       3                Sage, Mr. Frederick    male
# 324          325         0       3           Sage, Mr. George John Jr    male
# 792          793         0       3            Sage, Miss. Stella Anna  female
# 846          847         0       3           Sage, Mr. Douglas Bullen    male
# 863          864         0       3  Sage, Miss. Dorothy Edith "Dolly"  female
#
#      Age  SibSp  Parch    Ticket   Fare Cabin Embarked
# 159  NaN      8      2  CA. 2343  69.55   NaN        S
# 180  NaN      8      2  CA. 2343  69.55   NaN        S
# 201  NaN      8      2  CA. 2343  69.55   NaN        S
# 324  NaN      8      2  CA. 2343  69.55   NaN        S
# 792  NaN      8      2  CA. 2343  69.55   NaN        S
# ...

# %% [markdown]
# Also by fetching through ticket number we got 7 members. Which means either the remaining 4 members bought indiviual tickets, so now checking based on their Family name 'Sage'

# %%
df[df['Name'].str.contains('Sage')]
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 159          160         0       3         Sage, Master. Thomas Henry    male
# 180          181         0       3       Sage, Miss. Constance Gladys  female
# 201          202         0       3                Sage, Mr. Frederick    male
# 324          325         0       3           Sage, Mr. George John Jr    male
# 641          642         1       1               Sagesser, Mlle. Emma  female
# 792          793         0       3            Sage, Miss. Stella Anna  female
# 846          847         0       3           Sage, Mr. Douglas Bullen    male
# 863          864         0       3  Sage, Miss. Dorothy Edith "Dolly"  female
#
#       Age  SibSp  Parch    Ticket   Fare Cabin Embarked
# 159   NaN      8      2  CA. 2343  69.55   NaN        S
# 180   NaN      8      2  CA. 2343  69.55   NaN        S
# 201   NaN      8      2  CA. 2343  69.55   NaN        S
# ...

# %% [markdown]
# Here also we got 7 members the one is not 'Sage' it is 'Sagesser'.

# %% [markdown]
# So the remaining members are in test dataset

# %%
df1 = pd.read_csv('/content/test.csv')
df1.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df = pd.concat([df, df1])
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[df['Ticket'] == 'CA. 2343']
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 159          160       0.0       3         Sage, Master. Thomas Henry    male
# 180          181       0.0       3       Sage, Miss. Constance Gladys  female
# 201          202       0.0       3                Sage, Mr. Frederick    male
# 324          325       0.0       3           Sage, Mr. George John Jr    male
# 792          793       0.0       3            Sage, Miss. Stella Anna  female
# 846          847       0.0       3           Sage, Mr. Douglas Bullen    male
# 863          864       0.0       3  Sage, Miss. Dorothy Edith "Dolly"  female
# 188         1080       NaN       3                    Sage, Miss. Ada  female
# 342         1234       NaN       3              Sage, Mr. John George    male
# 360         1252       NaN       3        Sage, Master. William Henry    male
# 365         1257       NaN       3     Sage, Mrs. John (Annie Bullen)  female
#
# ...

# %% [markdown]
# So we got all 11 members now.

# %%
df['Ticket'].value_counts()
# Out:
# Ticket
# CA. 2343        11
# 1601             8
# CA 2144          8
# 347082           7
# S.O.C. 14879     7
#                 ..
# A.5. 3236        1
# 347086           1
# 365237           1
# 334915           1
# 28666            1
# Name: count, Length: 929, dtype: int64

# %%
df[df['Ticket'] == 'CA 2144']
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 59            60       0.0       3       Goodwin, Master. William Frederick
# 71            72       0.0       3               Goodwin, Miss. Lillian Amy
# 386          387       0.0       3          Goodwin, Master. Sidney Leonard
# 480          481       0.0       3           Goodwin, Master. Harold Victor
# 678          679       0.0       3  Goodwin, Mrs. Frederick (Augusta Tyler)
# 683          684       0.0       3              Goodwin, Mr. Charles Edward
# 139         1031       NaN       3           Goodwin, Mr. Charles Frederick
# 140         1032       NaN       3              Goodwin, Miss. Jessie Allis
#
#         Sex   Age  SibSp  Parch   Ticket  Fare Cabin Embarked
# 59     male  11.0      5      2  CA 2144  46.9   NaN        S
# 71   female  16.0      5      2  CA 2144  46.9   NaN        S
# 386    male   1.0      5      2  CA 2144  46.9   NaN        S
# ...

# %%
individual_fare = df['Fare'] / (df['SibSp'] + df['Parch'] + 1)

# %%
df.insert(10, 'individual_fare', individual_fare)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare  individual_fare Cabin Embarked
# 0      0         A/5 21171   7.2500          3.62500   NaN        S
# 1      0          PC 17599  71.2833         35.64165   C85        C
# 2      0  STON/O2. 3101282   7.9250          7.92500   NaN        S
# ...

# %%
df['individual_fare'].plot(kind='box')
# Out:
# <Axes: >

# %%
df[['individual_fare', 'Fare']].describe()
# Out:
#        individual_fare         Fare
# count      1308.000000  1308.000000
# mean         20.518215    33.295479
# std          35.774337    51.758668
# min           0.000000     0.000000
# 25%           7.452767     7.895800
# 50%           8.512483    14.454200
# 75%          24.237500    31.275000
# max         512.329200   512.329200

# %% [markdown]
# So there is one member who actually paid $500.

# %% [markdown]
# ## Feature Engineering on SibSp and Sparch cols

# %%
family_size = df['SibSp'] + df['Parch'] + 1

# %%
df.insert(8, 'family_size', family_size)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch  family_size            Ticket     Fare  individual_fare Cabin  \
# 0      0            2         A/5 21171   7.2500          3.62500   NaN
# 1      0            2          PC 17599  71.2833         35.64165   C85
# 2      0            1  STON/O2. 3101282   7.9250          7.92500   NaN
# ...

# %% [markdown]
# Creating a new feature call family_type. (Converting it to categorical col)
#
# 1 -> alone
#
# 2-4 -> small
#
# greater than 5 -> large

# %%
def transform_family_size(num):

  if num == 1:
    return 'alone'
  elif num > 1 and num < 5:
    return 'small'
  else:
    return 'large'

# %%
family_type = df['family_size'].apply(transform_family_size)

family_type
# Out:
# 0      small
# 1      small
# 2      alone
# 3      small
# 4      alone
#        ...
# 413    alone
# 414    alone
# 415    alone
# 416    alone
# 417    small
# Name: family_size, Length: 1309, dtype: object

# %%
df.insert(9, 'family_type', family_type)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch  family_size family_type            Ticket     Fare  individual_fare  \
# 0      0            2       small         A/5 21171   7.2500          3.62500
# 1      0            2       small          PC 17599  71.2833         35.64165
# 2      0            1       alone  STON/O2. 3101282   7.9250          7.92500
# ...

# %% [markdown]
# Now doing bivariate analysis based on Survived and family_type cols.

# %%
pd.crosstab(df['Survived'], df['family_type'], normalize='columns')*100
# Out:
# family_type      alone      large      small
# Survived
# 0.0          69.646182  83.870968  42.123288
# 1.0          30.353818  16.129032  57.876712

# %%
sns.heatmap(pd.crosstab(df['Survived'], df['family_type'], normalize='columns')*100)
# Out:
# <Axes: xlabel='family_type', ylabel='Survived'>

# %% [markdown]
# Some more feature engineering.

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Ectracting surnames from Name col to identify the family members.

surname = df['Name'].str.split(',').str.get(0).str.strip()

surname
# Out:
# 0             Braund
# 1            Cumings
# 2          Heikkinen
# 3           Futrelle
# 4              Allen
#            ...
# 413          Spector
# 414    Oliva y Ocana
# 415          Saether
# 416             Ware
# 417            Peter
# Name: Name, Length: 1309, dtype: object

# %%
df.insert(3, 'surname', surname)

# %%
df.head(3)
# Out:
#    PassengerId  Survived  Pclass    surname  \
# 0            1       0.0       3     Braund
# 1            2       1.0       1    Cumings
# 2            3       1.0       3  Heikkinen
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch  family_size family_type            Ticket     Fare  individual_fare  \
# 0      0            2       small         A/5 21171   7.2500          3.62500
# 1      0            2       small          PC 17599  71.2833         35.64165
# 2      0            1       alone  STON/O2. 3101282   7.9250          7.92500
#
#   Cabin Embarked
# 0   NaN        S
# 1   C85        C
# 2   NaN        S

# %% [markdown]
# Extracting title from the name.

# %%
title = df['Name'].str.split(',').str.get(1).str.strip().str.split(' ').str.get(0)

title
# Out:
# 0          Mr.
# 1         Mrs.
# 2        Miss.
# 3         Mrs.
# 4          Mr.
#         ...
# 413        Mr.
# 414      Dona.
# 415        Mr.
# 416        Mr.
# 417    Master.
# Name: Name, Length: 1309, dtype: object

# %%
df.insert(5, 'title', title)

# %%
df.head(3)
# Out:
#    PassengerId  Survived  Pclass    surname  \
# 0            1       0.0       3     Braund
# 1            2       1.0       1    Cumings
# 2            3       1.0       3  Heikkinen
#
#                                                 Name  title     Sex   Age  \
# 0                            Braund, Mr. Owen Harris    Mr.    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   Mrs.  female  38.0
# 2                             Heikkinen, Miss. Laina  Miss.  female  26.0
#
#    SibSp  Parch  family_size family_type            Ticket     Fare  \
# 0      1      0            2       small         A/5 21171   7.2500
# 1      1      0            2       small          PC 17599  71.2833
# 2      0      0            1       alone  STON/O2. 3101282   7.9250
#
#    individual_fare Cabin Embarked
# 0          3.62500   NaN        S
# 1         35.64165   C85        C
# 2          7.92500   NaN        S

# %% [markdown]
# Now doing univariate analysis on title col

# %%
df['title'].value_counts()
# Out:
# title
# Mr.          757
# Miss.        260
# Mrs.         197
# Master.       61
# Rev.           8
# Dr.            8
# Col.           4
# Major.         2
# Mlle.          2
# Ms.            2
# Mme.           1
# Don.           1
# Sir.           1
# Lady.          1
# Capt.          1
# the            1
# Jonkheer.      1
# Dona.          1
# Name: count, dtype: int64

# %%
# replacing the rare titles with 'other'

rare_titles = [
    'Rev.', 'Dr.', 'Col.', 'Major.', 'Capt.', 'the',
    'Jonkheer.', 'Don.', 'Dona.', 'Mlle.', 'Ms.',
    'Mme.', 'Sir.', 'Lady.'
]

# Replace exact matches only
df['title'] = df['title'].replace(rare_titles, 'other')

# %%
df['title'].value_counts()
# Out:
# title
# Mr.        757
# Miss.      260
# Mrs.       197
# Master.     61
# other       34
# Name: count, dtype: int64

# %%
df.sample(3)
# Out:
#      PassengerId  Survived  Pclass surname  \
# 759          760       1.0       1  Rothes
# 57            58       0.0       3   Novel
# 102          103       0.0       1   White
#
#                                                   Name  title     Sex   Age  \
# 759  Rothes, the Countess. of (Lucy Noel Martha Dye...  other  female  33.0
# 57                                 Novel, Mr. Mansouer    Mr.    male  28.5
# 102                          White, Mr. Richard Frasar    Mr.    male  21.0
#
#      SibSp  Parch  family_size family_type  Ticket     Fare  individual_fare  \
# 759      0      0            1       alone  110152  86.5000         86.50000
# 57       0      0            1       alone    2697   7.2292          7.22920
# 102      0      1            2       small   35281  77.2875         38.64375
#
#     Cabin Embarked
# 759   B77        S
# 57    NaN        C
# 102   D26        S

# %%
temp_df = df[df['title'].isin(['Mr.', 'Miss.', 'Mrs.', 'Master.', 'other'])]
temp_df
# Out:
#      PassengerId  Survived  Pclass        surname  \
# 0              1       0.0       3         Braund
# 1              2       1.0       1        Cumings
# 2              3       1.0       3      Heikkinen
# 3              4       1.0       1       Futrelle
# 4              5       0.0       3          Allen
# ..           ...       ...     ...            ...
# 413         1305       NaN       3        Spector
# 414         1306       NaN       1  Oliva y Ocana
# 415         1307       NaN       3        Saether
# 416         1308       NaN       3           Ware
# 417         1309       NaN       3          Peter
#
#                                                   Name    title     Sex   Age  \
# 0                              Braund, Mr. Owen Harris      Mr.    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...     Mrs.  female  38.0
# 2                               Heikkinen, Miss. Laina    Miss.  female  26.0
# ...

# %%
pd.crosstab(temp_df['Survived'], temp_df['title'], normalize='columns')*100
# Out:
# title     Master.     Miss.        Mr.  Mrs.      other
# Survived
# 0.0          42.5  30.21978  84.332689  20.8  55.555556
# 1.0          57.5  69.78022  15.667311  79.2  44.444444

# %% [markdown]
# So we can conclude that if you are a female you have more chances to survive.

# %% [markdown]
# ## Working with Cabin col

# %%
df['Cabin'].value_counts()
# Out:
# Cabin
# C23 C25 C27        6
# G6                 5
# B57 B59 B63 B66    5
# F33                4
# F4                 4
#                   ..
# C39                1
# B24                1
# D40                1
# D38                1
# C105               1
# Name: count, Length: 186, dtype: int64

# %%
print(df['Cabin'].isnull().sum())
# Out:
# 1014

# %%
print((df['Cabin'].isnull().sum()/len(df['Cabin']))*100)

# so there are 77% missing values in Cabin col
# Out:
# 77.46371275783041

# %%
df['Cabin'].fillna('M', inplace=True)

# %%
df['Cabin'].value_counts()
# Out:
# Cabin
# M                  1014
# C23 C25 C27           6
# G6                    5
# B57 B59 B63 B66       5
# F33                   4
#                    ...
# C39                   1
# B24                   1
# D40                   1
# D38                   1
# C105                  1
# Name: count, Length: 187, dtype: int64

# %%
deck = df['Cabin'].str[0]
deck
# Out:
# 0      M
# 1      C
# 2      M
# 3      C
# 4      M
#       ..
# 413    M
# 414    C
# 415    M
# 416    M
# 417    M
# Name: Cabin, Length: 1309, dtype: object

# %%
df.insert(16, 'deck', deck)

# %%
df.head(3)
# Out:
#    PassengerId  Survived  Pclass    surname  \
# 0            1       0.0       3     Braund
# 1            2       1.0       1    Cumings
# 2            3       1.0       3  Heikkinen
#
#                                                 Name  title     Sex   Age  \
# 0                            Braund, Mr. Owen Harris    Mr.    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   Mrs.  female  38.0
# 2                             Heikkinen, Miss. Laina  Miss.  female  26.0
#
#    SibSp  Parch  family_size family_type            Ticket     Fare  \
# 0      1      0            2       small         A/5 21171   7.2500
# 1      1      0            2       small          PC 17599  71.2833
# 2      0      0            1       alone  STON/O2. 3101282   7.9250
#
#    individual_fare Cabin deck Embarked
# 0          3.62500     M    M        S
# 1         35.64165   C85    C        C
# 2          7.92500     M    M        S

# %%
df['deck'].value_counts()
# Out:
# deck
# M    1014
# C      94
# B      65
# D      46
# E      41
# A      22
# F      21
# G       5
# T       1
# Name: count, dtype: int64

# %%
pd.crosstab(df['deck'], df['Pclass'])
# Out:
# Pclass   1    2    3
# deck
# A       22    0    0
# B       65    0    0
# C       94    0    0
# D       40    6    0
# E       34    4    3
# F        0   13    8
# G        0    0    5
# M       67  254  693
# T        1    0    0

# %%
pd.crosstab(df['deck'], df['Survived'], normalize='index').plot(kind='bar', stacked=True)
# Out:
# <Axes: xlabel='deck'>

# %% [markdown]
# The probability of survival depends on the deck

# %% [markdown]
# # Multivariate Analysis

# %%
df.corr(numeric_only=True)
# Out:
#                  PassengerId  Survived    Pclass       Age     SibSp  \
# PassengerId         1.000000 -0.005007 -0.038354  0.028814 -0.055224
# Survived           -0.005007  1.000000 -0.338481 -0.077221 -0.035322
# Pclass             -0.038354 -0.338481  1.000000 -0.408106  0.060832
# Age                 0.028814 -0.077221 -0.408106  1.000000 -0.243699
# SibSp              -0.055224 -0.035322  0.060832 -0.243699  1.000000
# Parch               0.008942  0.081629  0.018322 -0.150917  0.373587
# family_size        -0.031437  0.016639  0.050027 -0.240229  0.861952
# Fare                0.031428  0.257307 -0.558629  0.178740  0.160238
# individual_fare     0.035365  0.221600 -0.504270  0.193545 -0.089807
#
#                     Parch  family_size      Fare  individual_fare
# PassengerId      0.008942    -0.031437  0.031428         0.035365
# Survived         0.081629     0.016639  0.257307         0.221600
# Pclass           0.018322     0.050027 -0.558629        -0.504270
# ...

# %%
df.corr(numeric_only=True)['Survived']
# Out:
# PassengerId       -0.005007
# Survived           1.000000
# Pclass            -0.338481
# Age               -0.077221
# SibSp             -0.035322
# Parch              0.081629
# family_size        0.016639
# Fare               0.257307
# individual_fare    0.221600
# Name: Survived, dtype: float64

# %%
sns.heatmap(df.corr(numeric_only=True))

# the brighter the cell the stronger the correlation
# Out:
# <Axes: >

# %%
# another way of multivariate analysis

# %%
sns.pairplot(df1)
